# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('Playstore_Clean_Data.csv')
df.head()

# analysis on clean data
# Out:
#    Unnamed: 0                          App Name  \
# 0           0                           Gakondo
# 1           1               Ampere Battery Info
# 2           2                           GROW.me
# 3           3                            IMOCCI
# 4           4  Neon 3d Iron Tech Keyboard Theme
#
#                                   App Id         Category  Rating  \
# 0                    com.ishakwe.gakondo        Adventure     0.0
# 1             com.webserveis.batteryinfo            Tools     4.4
# 2                   com.horodyski.grower            Tools     0.0
# 3                             com.imocci           Social     0.0
# 4  com.ikeyboard.theme.neon_3d.iron.tech  Personalization     4.7
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  ...  \
# 0             0        10                10                15  True  ...
# 1            64      5000              5000              7662  True  ...
# ...

# %%
df.shape
# Out:
# (12657, 23)

# %%
df.describe()
# Out:
#          Unnamed: 0        Rating  Rating Count      Installs  \
# count  12657.000000  12657.000000  1.265700e+04  1.265700e+04
# mean    6328.000000      2.307869  2.352402e+03  1.413480e+05
# std     3653.905513      2.091417  3.430005e+04  1.928992e+06
# min        0.000000      0.000000  0.000000e+00  0.000000e+00
# 25%     3164.000000      0.000000  0.000000e+00  1.000000e+02
# 50%     6328.000000      3.300000  7.000000e+00  5.000000e+02
# 75%     9492.000000      4.300000  6.000000e+01  1.000000e+04
# max    12656.000000      5.000000  1.848736e+06  1.000000e+08
#
#        Minimum Installs  Maximum Installs         Price          Size
# count      1.265700e+04      1.265700e+04  12657.000000  12657.000000
# mean       1.413480e+05      2.389660e+05      0.116925     26.057810
# std        1.928992e+06      2.749090e+06      2.035941     63.959208
# min        0.000000e+00      0.000000e+00      0.000000      1.000000
# ...

# %% [markdown]
# # Numerical Data

# %% [markdown]
# # 1. Boxplot 🎁🎁🎁

# %%
# 1. boxPlot

# %%
import seaborn as sns
sns.boxplot(df['Rating'])

# boxplot on numrical data only
# Out:
# <Axes: >

# %%
sns.boxplot(df['Rating Count'])
# Out:
# <Axes: >

# %%
(df['Rating Count']).value_counts()
# Out:
# 0         5519
# 5          343
# 7          276
# 6          275
# 8          196
#           ...
# 155083       1
# 4508         1
# 336          1
# 1713         1
# 21228        1
# Name: Rating Count, Length: 1595, dtype: int64

# %%
sns.boxplot(df['Installs'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Minimum Installs'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Maximum Installs'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Size'])
# Out:
# <Axes: >

# %% [markdown]
# # 2. Histogram📊📊📊

# %%
# Numerical data 
# univarient analysis

# %%
sns.histplot(df['Rating'],bins=6)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(df['Rating Count'],bins=6)
# Out:
# <Axes: xlabel='Rating Count', ylabel='Count'>

# %%
df['Rating Count'].max()
# Out:
# 1848736

# %%
sns.histplot(df['Installs'],bins=6)
# Out:
# <Axes: xlabel='Installs', ylabel='Count'>

# %%
sns.histplot(df['Minimum Installs'],bins=6)
# Out:
# <Axes: xlabel='Minimum Installs', ylabel='Count'>

# %%
sns.histplot(df['Maximum Installs'],bins=6)
# Out:
# <Axes: xlabel='Maximum Installs', ylabel='Count'>

# %%
sns.histplot(df['Price'],bins=6)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(df['Size'],bins=6)
# Out:
# <Axes: xlabel='Size', ylabel='Count'>

# %% [markdown]
# # 3. DistPlot📉📉📉

# %%
sns.distplot(df['Rating'],bins=6)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13108\3792358540.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Rating'],bins=6)
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df['Size'],bins=6)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13108\3890637091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Size'],bins=6)
# <Axes: xlabel='Size', ylabel='Density'>

# %%
sns.distplot(df['Price'],bins=6)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13108\4069911299.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],bins=6)
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# # Categorical Data

# %% [markdown]
# # 1. Countplot

# %%
# catgorical data

sns.countplot(df, x=df['Category'].head())
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(df, x=df['Currency'])
# Out:
# <Axes: xlabel='Currency', ylabel='count'>

# %%
sns.countplot(df, x=df['Content Rating'])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.countplot(df, y=df['Developer Email'].head(5))
# Out:
# <Axes: xlabel='count', ylabel='Developer Email'>

# %% [markdown]
# # 2. pie chart

# %%
df['Content Rating'].value_counts().plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='Content Rating'>

# %%
df['Category'].value_counts().plot(kind='pie', autopct= "%0.2f")
# Out:
# <Axes: ylabel='Category'>

# %%
df['Category'].value_counts().head(5).plot(kind='pie', autopct= "%0.2f")
# Out:
# <Axes: ylabel='Category'>

# %%
df['Category'].value_counts().tail(5).plot(kind='pie', autopct= "%0.2f")
# Out:
# <Axes: ylabel='Category'>

# %%
df['Currency'].value_counts().head(2).plot(kind='pie', autopct= "%0.2f")
# Out:
# <Axes: ylabel='Currency'>

# %%
df['Editors Choice'].value_counts()
# Out:
# False    12651
# True         6
# Name: Editors Choice, dtype: int64

# %%
df['Editors Choice'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['In App Purchases'].value_counts()
# Out:
# False    11423
# True      1234
# Name: In App Purchases, dtype: int64

# %%
df['In App Purchases'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Ad Supported'].value_counts()
# Out:
# False    7074
# True     5583
# Name: Ad Supported, dtype: int64

# %%
df['Ad Supported'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           11025
# Teen                1092
# Mature 17+           338
# Everyone 10+         200
# Adults only 18+        1
# Unrated                1
# Name: Content Rating, dtype: int64

# %%
df['Content Rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Privacy Policy'].value_counts().head(5)
# Out:
# http://www.subsplash.com/legal/privacy           74
# http://www.trainerize.com/privacy.aspx           61
# http://www.chownow.com/privacy-policy            42
# https://www.mindbodyonline.com/privacy-policy    30
# https://arely.net/Privacy_Policy.html            26
# Name: Privacy Policy, dtype: int64

# %%
df['Privacy Policy'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Developer Website'].value_counts().head(5)
# Out:
# http://www.subsplash.com/                      75
# http://www.chownow.com                         42
# https://foodsoul.pro                           20
# https://www.mindbodyonline.com/branded-apps    18
# https://vsxapps.com/currencyx                  17
# Name: Developer Website, dtype: int64

# %%
df['Developer Website'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Developer Email'].value_counts().head(5)
# Out:
# appsupport@subsplash.com      75
# help@trainerize.com           54
# eng-android@chownow.com       43
# support@mindbodyonline.com    28
# android@foodsoul.pro          20
# Name: Developer Email, dtype: int64

# %%
df['Developer Email'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Developer Id'].value_counts().head(5)
# Out:
# Subsplash Inc                61
# TRAINERIZE                   60
# ChowNow                      43
# #NAME?                       20
# Currency Converter X Apps    17
# Name: Developer Id, dtype: int64

# %%
df['Developer Id'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Currency'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Free'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Category'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['App Name'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >
